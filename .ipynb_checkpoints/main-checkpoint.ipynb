# %%
##IMPORTS##
import psycopg2
import numpy as np

# %%
##ENVs and GLOBAL VARIABLES##
dbname = "census"
user = "nightfury"
host = "localhost"
password = ""
db_relation = "adult"

measure_attributes=['age','fnlwgt', 'education_num','capital_gain','capital_loss','hours_per_week']
groupby_attributes=['workclass','education','occupation','relationship','race','sex','native_country','salary_range']
aggregate_functions=['sum','avg','max','min','count']

measure_attributes=['age','capital_gain','hours_per_week']
groupby_attributes=['workclass','relationship','sex']
aggregate_functions=['avg','count']

# %%
#Connecting with local db
try:
    conn = psycopg2.connect(f"dbname='{dbname}' user='{user}' host='{host}' password='{password}'")
except Exception as e:
    print (f"Unable to connect to the database. Error: {str(e)}")

# %%
cur = conn.cursor()

# %%
#Getting user input
reference_db = input("Enter the reference DB.")
print(f"The reference db is {reference_db}")
# Out:
# What is the reference DB.full
# The reference db is full

# %%
cur.execute(f"""SELECT * from {db_relation}""")

# %%
##UTIL FUNCTIONS##

def get_all_combinations(groupby_attributes, measure_attributes, aggregate_functions):
    combinations = np.array(np.meshgrid(groupby_attributes, measure_attributes, aggregate_functions)).T.reshape(-1,3)

def query_generator(groupby_attribute, measure_attribute, aggregate_function, target_relation, reference_relation):
    target_query = f"""SELECT {groupby_attribute}, {aggregate_function}({measure_attribute}) FROM {target_relation} GROUP BY {groupby_attribute}"""
    reference_query = f"""SELECT {groupby_attribute}, {aggregate_function}({measure_attribute}) FROM {reference_relation} GROUP BY {groupby_attribute}"""
    return target_query, reference_query

def

# %%
combinations
# Out:
# array([['workclass', 'age', 'sum'],
#        ['workclass', 'fnlwgt', 'sum'],
#        ['workclass', 'education_num', 'sum'],
#        ['workclass', 'capital_gain', 'sum'],
#        ['workclass', 'capital_loss', 'sum'],
#        ['workclass', 'hours_per_week', 'sum'],
#        ['education', 'age', 'sum'],
#        ['education', 'fnlwgt', 'sum'],
#        ['education', 'education_num', 'sum'],
#        ['education', 'capital_gain', 'sum'],
#        ['education', 'capital_loss', 'sum'],
#        ['education', 'hours_per_week', 'sum'],
#        ['occupation', 'age', 'sum'],
#        ['occupation', 'fnlwgt', 'sum'],
#        ['occupation', 'education_num', 'sum'],
#        ['occupation', 'capital_gain', 'sum'],
#        ['occupation', 'capital_loss', 'sum'],
#        ['occupation', 'hours_per_week', 'sum'],
#        ['relationship', 'age', 'sum'],
#        ['relationship', 'fnlwgt', 'sum'],
#        ['relationship', 'education_num', 'sum'],
#        ['relationship', 'capital_gain', 'sum'],
#        ['relationship', 'capital_loss', 'sum'],
#        ['relationship', 'hours_per_week', 'sum'],
#        ['race', 'age', 'sum'],
#        ['race', 'fnlwgt', 'sum'],
#        ['race', 'education_num', 'sum'],
#        ['race', 'capital_gain', 'sum'],
#        ['race', 'capital_loss', 'sum'],
#        ['race', 'hours_per_week', 'sum'],
#        ['sex', 'age', 'sum'],
#        ['sex', 'fnlwgt', 'sum'],
#        ['sex', 'education_num', 'sum'],
#        ['sex', 'capital_gain', 'sum'],
#        ['sex', 'capital_loss', 'sum'],
#        ['sex', 'hours_per_week', 'sum'],
#        ['native_country', 'age', 'sum'],
#        ['native_country', 'fnlwgt', 'sum'],
#        ['native_country', 'education_num', 'sum'],
#        ['native_country', 'capital_gain', 'sum'],
#        ['native_country', 'capital_loss', 'sum'],
#        ['native_country', 'hours_per_week', 'sum'],
#        ['salary_range', 'age', 'sum'],
#        ['salary_range', 'fnlwgt', 'sum'],
#        ['salary_range', 'education_num', 'sum'],
#        ['salary_range', 'capital_gain', 'sum'],
#        ['salary_range', 'capital_loss', 'sum'],
#        ['salary_range', 'hours_per_week', 'sum'],
#        ['workclass', 'age', 'avg'],
#        ['workclass', 'fnlwgt', 'avg'],
#        ['workclass', 'education_num', 'avg'],
#        ['workclass', 'capital_gain', 'avg'],
#        ['workclass', 'capital_loss', 'avg'],
#        ['workclass', 'hours_per_week', 'avg'],
#        ['education', 'age', 'avg'],
#        ['education', 'fnlwgt', 'avg'],
#        ['education', 'education_num', 'avg'],
#        ['education', 'capital_gain', 'avg'],
#        ['education', 'capital_loss', 'avg'],
#        ['education', 'hours_per_week', 'avg'],
#        ['occupation', 'age', 'avg'],
#        ['occupation', 'fnlwgt', 'avg'],
#        ['occupation', 'education_num', 'avg'],
#        ['occupation', 'capital_gain', 'avg'],
#        ['occupation', 'capital_loss', 'avg'],
#        ['occupation', 'hours_per_week', 'avg'],
#        ['relationship', 'age', 'avg'],
#        ['relationship', 'fnlwgt', 'avg'],
#        ['relationship', 'education_num', 'avg'],
#        ['relationship', 'capital_gain', 'avg'],
#        ['relationship', 'capital_loss', 'avg'],
#        ['relationship', 'hours_per_week', 'avg'],
#        ['race', 'age', 'avg'],
#        ['race', 'fnlwgt', 'avg'],
#        ['race', 'education_num', 'avg'],
#        ['race', 'capital_gain', 'avg'],
#        ['race', 'capital_loss', 'avg'],
#        ['race', 'hours_per_week', 'avg'],
#        ['sex', 'age', 'avg'],
#        ['sex', 'fnlwgt', 'avg'],
#        ['sex', 'education_num', 'avg'],
#        ['sex', 'capital_gain', 'avg'],
#        ['sex', 'capital_loss', 'avg'],
#        ['sex', 'hours_per_week', 'avg'],
#        ['native_country', 'age', 'avg'],
#        ['native_country', 'fnlwgt', 'avg'],
#        ['native_country', 'education_num', 'avg'],
#        ['native_country', 'capital_gain', 'avg'],
#        ['native_country', 'capital_loss', 'avg'],
#        ['native_country', 'hours_per_week', 'avg'],
#        ['salary_range', 'age', 'avg'],
#        ['salary_range', 'fnlwgt', 'avg'],
#        ['salary_range', 'education_num', 'avg'],
#        ['salary_range', 'capital_gain', 'avg'],
#        ['salary_range', 'capital_loss', 'avg'],
#        ['salary_range', 'hours_per_week', 'avg'],
#        ['workclass', 'age', 'max'],
#        ['workclass', 'fnlwgt', 'max'],
#        ['workclass', 'education_num', 'max'],
#        ['workclass', 'capital_gain', 'max'],
#        ['workclass', 'capital_loss', 'max'],
#        ['workclass', 'hours_per_week', 'max'],
#        ['education', 'age', 'max'],
#        ['education', 'fnlwgt', 'max'],
#        ['education', 'education_num', 'max'],
#        ['education', 'capital_gain', 'max'],
#        ['education', 'capital_loss', 'max'],
#        ['education', 'hours_per_week', 'max'],
#        ['occupation', 'age', 'max'],
#        ['occupation', 'fnlwgt', 'max'],
#        ['occupation', 'education_num', 'max'],
#        ['occupation', 'capital_gain', 'max'],
#        ['occupation', 'capital_loss', 'max'],
#        ['occupation', 'hours_per_week', 'max'],
#        ['relationship', 'age', 'max'],
#        ['relationship', 'fnlwgt', 'max'],
#        ['relationship', 'education_num', 'max'],
#        ['relationship', 'capital_gain', 'max'],
#        ['relationship', 'capital_loss', 'max'],
#        ['relationship', 'hours_per_week', 'max'],
#        ['race', 'age', 'max'],
#        ['race', 'fnlwgt', 'max'],
#        ['race', 'education_num', 'max'],
#        ['race', 'capital_gain', 'max'],
#        ['race', 'capital_loss', 'max'],
#        ['race', 'hours_per_week', 'max'],
#        ['sex', 'age', 'max'],
#        ['sex', 'fnlwgt', 'max'],
#        ['sex', 'education_num', 'max'],
#        ['sex', 'capital_gain', 'max'],
#        ['sex', 'capital_loss', 'max'],
#        ['sex', 'hours_per_week', 'max'],
#        ['native_country', 'age', 'max'],
#        ['native_country', 'fnlwgt', 'max'],
#        ['native_country', 'education_num', 'max'],
#        ['native_country', 'capital_gain', 'max'],
#        ['native_country', 'capital_loss', 'max'],
#        ['native_country', 'hours_per_week', 'max'],
#        ['salary_range', 'age', 'max'],
#        ['salary_range', 'fnlwgt', 'max'],
#        ['salary_range', 'education_num', 'max'],
#        ['salary_range', 'capital_gain', 'max'],
#        ['salary_range', 'capital_loss', 'max'],
#        ['salary_range', 'hours_per_week', 'max'],
#        ['workclass', 'age', 'min'],
#        ['workclass', 'fnlwgt', 'min'],
#        ['workclass', 'education_num', 'min'],
#        ['workclass', 'capital_gain', 'min'],
#        ['workclass', 'capital_loss', 'min'],
#        ['workclass', 'hours_per_week', 'min'],
#        ['education', 'age', 'min'],
#        ['education', 'fnlwgt', 'min'],
#        ['education', 'education_num', 'min'],
#        ['education', 'capital_gain', 'min'],
#        ['education', 'capital_loss', 'min'],
#        ['education', 'hours_per_week', 'min'],
#        ['occupation', 'age', 'min'],
#        ['occupation', 'fnlwgt', 'min'],
#        ['occupation', 'education_num', 'min'],
#        ['occupation', 'capital_gain', 'min'],
#        ['occupation', 'capital_loss', 'min'],
#        ['occupation', 'hours_per_week', 'min'],
#        ['relationship', 'age', 'min'],
#        ['relationship', 'fnlwgt', 'min'],
#        ['relationship', 'education_num', 'min'],
#        ['relationship', 'capital_gain', 'min'],
#        ['relationship', 'capital_loss', 'min'],
#        ['relationship', 'hours_per_week', 'min'],
#        ['race', 'age', 'min'],
#        ['race', 'fnlwgt', 'min'],
#        ['race', 'education_num', 'min'],
#        ['race', 'capital_gain', 'min'],
#        ['race', 'capital_loss', 'min'],
#        ['race', 'hours_per_week', 'min'],
#        ['sex', 'age', 'min'],
#        ['sex', 'fnlwgt', 'min'],
#        ['sex', 'education_num', 'min'],
#        ['sex', 'capital_gain', 'min'],
#        ['sex', 'capital_loss', 'min'],
#        ['sex', 'hours_per_week', 'min'],
#        ['native_country', 'age', 'min'],
#        ['native_country', 'fnlwgt', 'min'],
#        ['native_country', 'education_num', 'min'],
#        ['native_country', 'capital_gain', 'min'],
#        ['native_country', 'capital_loss', 'min'],
#        ['native_country', 'hours_per_week', 'min'],
#        ['salary_range', 'age', 'min'],
#        ['salary_range', 'fnlwgt', 'min'],
#        ['salary_range', 'education_num', 'min'],
#        ['salary_range', 'capital_gain', 'min'],
#        ['salary_range', 'capital_loss', 'min'],
#        ['salary_range', 'hours_per_week', 'min'],
#        ['workclass', 'age', 'count'],
#        ['workclass', 'fnlwgt', 'count'],
#        ['workclass', 'education_num', 'count'],
#        ['workclass', 'capital_gain', 'count'],
#        ['workclass', 'capital_loss', 'count'],
#        ['workclass', 'hours_per_week', 'count'],
#        ['education', 'age', 'count'],
#        ['education', 'fnlwgt', 'count'],
#        ['education', 'education_num', 'count'],
#        ['education', 'capital_gain', 'count'],
#        ['education', 'capital_loss', 'count'],
#        ['education', 'hours_per_week', 'count'],
#        ['occupation', 'age', 'count'],
#        ['occupation', 'fnlwgt', 'count'],
#        ['occupation', 'education_num', 'count'],
#        ['occupation', 'capital_gain', 'count'],
#        ['occupation', 'capital_loss', 'count'],
#        ['occupation', 'hours_per_week', 'count'],
#        ['relationship', 'age', 'count'],
#        ['relationship', 'fnlwgt', 'count'],
#        ['relationship', 'education_num', 'count'],
#        ['relationship', 'capital_gain', 'count'],
#        ['relationship', 'capital_loss', 'count'],
#        ['relationship', 'hours_per_week', 'count'],
#        ['race', 'age', 'count'],
#        ['race', 'fnlwgt', 'count'],
#        ['race', 'education_num', 'count'],
#        ['race', 'capital_gain', 'count'],
#        ['race', 'capital_loss', 'count'],
#        ['race', 'hours_per_week', 'count'],
#        ['sex', 'age', 'count'],
#        ['sex', 'fnlwgt', 'count'],
#        ['sex', 'education_num', 'count'],
#        ['sex', 'capital_gain', 'count'],
#        ['sex', 'capital_loss', 'count'],
#        ['sex', 'hours_per_week', 'count'],
#        ['native_country', 'age', 'count'],
#        ['native_country', 'fnlwgt', 'count'],
#        ['native_country', 'education_num', 'count'],
#        ['native_country', 'capital_gain', 'count'],
#        ['native_country', 'capital_loss', 'count'],
#        ['native_country', 'hours_per_week', 'count'],
#        ['salary_range', 'age', 'count'],
#        ['salary_range', 'fnlwgt', 'count'],
#        ['salary_range', 'education_num', 'count'],
#        ['salary_range', 'capital_gain', 'count'],
#        ['salary_range', 'capital_loss', 'count'],
#        ['salary_range', 'hours_per_week', 'count']], dtype='<U14')
